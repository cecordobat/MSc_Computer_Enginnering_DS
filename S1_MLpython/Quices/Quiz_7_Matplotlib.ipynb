# %% [markdown]
# <a href="https://colab.research.google.com/github/cecordobat/MSc_Computer_Enginnering_DS/blob/main/S1_M4/Quiz_7_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src = "https://drive.google.com/uc?export=view&id=1rSrsZ04aJ_D3BC67Cy2dBUZ6tmguydNf" alt = "Encabezado MLDS" width = "100%">  </img>

# %% [markdown]
# #**Quiz 7 : Visualización de datos con *Matplotlib***
# ---
#
# Este es un quiz para practicar las habilidades adquiridas usando *Matplotlib*  para construir visualizaciones de datos. En esta actividad usted deberá recrear dos visualizaciones de datos.
#
#
# > **Nota:** Esta tarea va a ser calificada estableciendo una conexión con **[UNCode](https://juezun.github.io/)**. La conexión se realizará al ejecutar la celda indicada e ingresando los datos de usuariio.En cada ejercicio se indicará si es calificable o no, también los lugares donde debe escribir su código sin modificar lo demás con un aproximado de cantidad de líneas a escribir. No se preocupe si su código toma más líneas, esto es simplemente un aproximado destinado a que pueda replantear su estrategia si el código está tomando más de las esperadas. No es un requisito estricto y soluciones más largas también son válidas.
#
# > **La tarea es incremental, es recomendable resolver los puntos en orden.**
#
# > En caso de tener dudas de cómo solucionar este tipo de ejercicios, por favor consultar el demo en la unidad 0

# %% [markdown]
# Ejecute la siguiente celda para importar las librerías.

# %%
#Importar librerías
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#TEST_CELL
# !python --version
print('Pandas', pd.__version__)
print('NumPy', np.__version__)
print('Matplotlib', mpl.__version__)
# Out:
# Python 3.10.12
# Pandas 2.1.4
# NumPy 1.26.4
# Matplotlib 3.7.1

# %% [markdown]
# Este material fue realizado con las siguientes versiones:
#
# - Python 3.10.12
# - NumPy 2.1.4
# - Pandas 1.26.4
# - Matplotlib 3.7.1

# %%
# !pip install rlxcrypt
# !wget --no-cache -O session.pye -q https://raw.githubusercontent.com/JuezUN/INGInious/master/external%20libs/session.pye
# Out:
# Collecting rlxcrypt
#   Downloading rlxcrypt-0.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Collecting imphook (from rlxcrypt)
#   Downloading imphook-1.0.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from rlxcrypt) (3.0.11)
# Collecting pycryptodome (from rlxcrypt)
#   Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.10/dist-packages (from rlxcrypt) (43.0.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography->rlxcrypt) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography->rlxcrypt) (2.22)
# Downloading rlxcrypt-0.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.9/297.9 kB 6.2 MB/s eta 0:00:00
# Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 12.1 MB/s eta 0:00:00
# Building wheels for collected packages: imphook
#   Building wheel for imphook (setup.py) ... done
#   Created wheel for imphook: filename=imphook-1.0-py3-none-any.whl size=9421 sha256=801e30b4abae434b3385e91f7d9b468efbe9557c7df9cf40edc40540d9d2dda8
#   Stored in directory: /root/.cache/pip/wheels/dc/e2/a4/fcb3817d09a2eb047b2b08eb58e7d9140041b0f3f415eb1256
# Successfully built imphook
# Installing collected packages: imphook, pycryptodome, rlxcrypt
# Successfully installed imphook-1.0 pycryptodome-3.20.0 rlxcrypt-0.0.4

# %%
import rlxcrypt
import session

grader = session.LoginSequence("AYVDDCP-GroupMLDS-1-2024-2@quiz_7")
# Out:
#     <div>
#     <div style="display: flex">
#         <div style="padding: 10px">
#           <img
#             src="https://uncode.unal.edu.co/static/images/logo_unc.svg"
#             width="50px"
#             height="50px"
#           />
#         </div>
#
#         <div>
#           <h2>UNCode Notebooks grader API</h2>
#           <hr />
#         </div>
#       </div>
#
#       <div style="display: flex">
#         <span>Please enter authentication data</span>
#       </div>
#     </div>
# Please enter your UNCode username: cecordobat
# Please enter your password: ··········
# <h5 style="color: green"><Response [200]></h5>
# <h5 style="color: green">Auth process succeeded</h5>
# <h5>View your courses <a href="https://uncode.unal.edu.co/courselist">at UNCode platform</a></h5>
# <h3>You will sumbit code to course: <span style="color: green">Análisis y visualización de datos con Python | Grupo MLDS-1 | 2024 - 2<span></h3>
# <h3>You will sumbit code to task: <span style="color: blue">Unidad 4 - Quiz 7 - Visualización de datos con matplotlib<span></h3>

# %% [markdown]
# ## **0. Datos**
# ---
#
# Vamos a crear tres arreglos de *Numpy* con los cuales construiremos las gráficas propuestas. Estos serán usados como ejemplo por defecto y como referencia para el desarrollo de los ejercicios.

# %%
# Creando los datos  (EJECUTE ESTA CELDA SIN MODIFICARLA)
x = np.linspace(0, 100, 10000)
y = x**2
z = x*2

# %% [markdown]
# ## **1. Gráfica con *zoom***
# ---
#
# Para este ejercicio deberá usar los valores de los arreglos **`x`**, y **`y`** para reproducir la siguiente visualización:
#
# ![alt text](https://drive.google.com/uc?export=view&id=1Wbi4cl9ORZz_GnkSqhs2r7lMFWIB4Qt7)
#
# La figura está compuesta por dos objetos **`Axes`** de *Matplotlib*: uno grande con la vista de todos los datos y uno más pequeño (interno) que representa un *zoom* o acercamiento en una parte específica de los datos. Los **Axes** tienen las siguientes propiedades:
#
# * Ambas gráficas hacen parte de la figura llamada **`fig1`**.
# * **Gráfica mayor (`ax1_mayor`):** Esta gráfica representa los valores de los arreglos **`x`** en el eje $x$ y **`y`** en el eje $y$. Ocupa todo el tamaño disponible de la figura.
# * **Gráfica menor: (`ax1_menor`)** Esta gráfica representa los valores de los arreglos **`x`** en el eje $x$ y **`y`** en el eje $y$. Su tamaño es el $40\%$ de la figura mayor, empezando en $1/5$ de la pantalla en $x$ y en la mitad de la pantalla en $y$. Sus límites en ambos ejes no son los límites por defecto, debe ajustarlos para hacer el zoom en la zona de interés del arreglo **`x`** mostrada en el gráfico.
# * Debe cumplir con los atributos mostrados en la imágen de ejemplo: color de la línea, etiquetas de los ejes, límites y títulos
#
#
# > **NOTA: Los comandos para graficar y modificar una figura deberían ir todos en la misma celda. Separarlos en celdas distintas puede causar que no se grafique nada.**

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pistas</b></font>
# </summary>
# <p>
#
# * Ponga especial atención a los detalles. Elementos como las etiquetas de los ejes o los títulos de las gráficas no son generadas por defecto y puede necesitar definirlas.
# * La posición en la Figura se define con el método **`fig.add_axes`**. Las posiciones de los **`Axes`** son valores numéricos de $0.0$ a $1.0$, representando porcentajes de la figura de la siguiente forma:
#   > **[`inicio_x, inicio_y, ancho, alto`]**
#
# * Los límites de cada gráfica son exactamente los mostrados en la imagen de referencia. No se preocupe por representar proporciones exactas y utilice los límites exactos con funciones como **`set_xlim`** y **`set_ylim`**.
# * Para los colores, no es necesario que utilice ningún código especial. Es suficiente con definir el nombre del color en inglés en el parámetro **`color`** del método **``plot``**.
# * Detalles como el **`dpi`** o el **`tight_layout`** no son calificados, pero se recomienda no modificar para que la referencia de salida esperada corresponda y sea más fácil identificar las diferencias.
# * Las palabras usadas en ejes, títulos y leyendas son cadenas de texto sin espacios adicionales en sus extremos.
# </p>

# %%
#VARIABLES CALIFICADAS: ax1_mayor, ax1_menor

fig1 = plt.figure(dpi = 120)

### ESCRIBA SU CÓDIGO AQUÍ ### (~ 13 líneas de código)

ax1_mayor = fig1.add_axes([0, 0, 1, 1])  # [inicio_x, inicio_y, ancho, alto]
ax1_mayor.plot(x, y, color='green')
ax1_mayor.set_title('Gráfica Mayor')
ax1_mayor.set_xlabel('x')
ax1_mayor.set_ylabel('y')
ax1_mayor.set_xlim(0, 100)  # Límite esperado en x
ax1_mayor.set_ylim(0, 10000)  # Límite esperado en y


ax1_menor = fig1.add_axes([0.2, 0.5, 0.4, 0.4])  # [inicio_x, inicio_y, ancho, alto]
ax1_menor.plot(x, y, color='green')
ax1_menor.set_xlim(0, 20)
ax1_menor.set_ylim(0, 400)
ax1_menor.set_title('zoom')
ax1_menor.set_xlabel('x')
ax1_menor.set_ylabel('y')


### FIN DEL CÓDIGO ###
fig1.show()

# %% [markdown]
# **Salida esperada:**
#
# ![Ejercicio 1.png](data:image/png;base64,...)

# %% [markdown]
# ### **Evaluar código**

# %%
grader.run_test("Test 1_1", globals())
# Out:
# Test 1_1
# <h4>Test Run correctly</h4>
# <h6 style="color: green;">Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>

# %%
grader.run_test("Test 1_2", globals())
# Out:
# Test 1_2
# <h4>Test Run correctly</h4>
# <h6 style="color: green;">Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>

# %%
grader.run_test("Test 1_3", globals())
# Out:
# Test 1_3
# <h4>Test Run correctly</h4>
# <h6 style="color: green;">Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>

# %% [markdown]
# ## **2. Gráficas paralelas**
# ---
#
# Para este ejercicio deberá usar los valores de los arreglos **`x`**, **`y`** y **`z`** para recrear la siguiente visualización compuesta por dos objetos **`Axes`**:
#
# ![alt text](https://drive.google.com/uc?export=view&id=1WDnaPUNBwajAGs8WyAU58u8TS8QJetsO)
#
# En esta ocasión, cada uno de los objetos **`Axes`** estarán uno al lado del otro. Estas dos gráficas tendrán las siguientes propiedades:
# * Ambas gráficas hacen parte de la figura **`fig2`**. Esta figura tendrá 1 fila y 2 columnas, generadas con el método **`subplots`**.
# * **Gráfica izquierda (`ax2_izq`):** Esta gráfica representa los valores de los arreglos **`x`** en el eje $x$ y **`y`** en el eje $y$. Es una gráfica de líneas de color azul, con $3$ puntos de grosor de línea y con estilo de línea con guiones.
# * **Gráfica derecha (`ax2_der`):** Esta gráfica representa los valores de los arreglos **`x`** en el eje $x$ y **`z`** en el eje $y$. Es una gráfica de líneas de color rojo, con $3$ puntos de grosor de línea y con estilo de línea intermitente de guion y punto.
#
# > **NOTA: Los comandos para graficar y modificar una figura deberían ir todos en la misma celda. Separarlos en celdas distintas puede causar que no se grafique nada.**

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Pistas</b></font>
# </summary>
#
# * Ponga especial atención a los detalles. Elementos como las etiquetas de los ejes o los títulos de las gráficas no son generadas por defecto y puede necesitar definirlas.
# * En esta ocasión deberá utilizar el método **`subplots`** para generar los **`Axes`** y la figura correspondiente.
# * Para los colores, no es necesario que utilice ningún código especial. Es suficiente con definir el nombre del color en inglés en el parámetro **`color`** del método **``plot``**.
# * Consulte las opciones de [estilo de línea](https://matplotlib.org/gallery/lines_bars_and_markers/line_styles_reference.html) de *Matplotlib* para saber cuál es el correcto. Use la notación con símbolos del parámetro **`ls`**, en vez de las palabras reservadas. Por ejemplo, use **`-`** para un estilo de línea continuo.
# * Detalles como el **`dpi`** o el **`tight_layout`** no son calificados, pero se recomienda que la salida esperada corresponda con la referencia para que sea más fácil identificar las diferencias.
# * Las palabras usadas en ejes, títulos y leyendas son cadenas de texto sin espacios adicionales en sus extremos.

# %%
#VARIABLES CALIFICADAS: ax2_izq, ax2_der

fig2, (ax2_izq, ax2_der) = plt.subplots(tight_layout=True,
                                        dpi = 120,
                                        nrows=1,
                                        ncols=2)
### ESCRIBA SU CÓDIGO AQUÍ ### (~ 4 líneas de código)

ax2_izq.plot(x, y, color='blue', linewidth=3, ls='--')  # Línea con guiones
ax2_izq.set_title('Izquierda')
ax2_izq.set_xlabel('x')
ax2_izq.set_ylabel('y')

# Gráfica derecha (ax2_der)
ax2_der.plot(x, z, color='red', linewidth=3, ls='-.')  # Línea intermitente (guion y punto)
ax2_der.set_title('Derecha')
ax2_der.set_xlabel('x')
ax2_der.set_ylabel('z')


### FIN DEL CÓDIGO ###
fig2.show()

# %% [markdown]
# **Salida esperada:**
#
# ![Ejercicio 2.png](data:image/png;base64,...)

# %% [markdown]
# ### **Evaluar código**

# %%
grader.run_test("Test 2_1", globals())
# Out:
# Test 2_1
# <h4>Test Run correctly</h4>
# <h6 style="color: green;">Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>

# %%
grader.run_test("Test 2_2", globals())
# Out:
# Test 2_2
# <h4>Test Run correctly</h4>
# <h6 style="color: green;">Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>

# %%
grader.run_test("Test 2_3", globals())
# Out:
# Test 2_3
# <h4>Test Run correctly</h4>
# <h6 style="color: green;">Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>

# %% [markdown]
# ## **Evaluación**
# **¡Felicitaciones!** Ha terminado el quiz. ¡Buen trabajo!

# %%
grader.submit_task(globals())
# Out:
# Test 1_1
# Test 1_2
# Test 1_3
# Test 2_1
# Test 2_2
# Test 2_3
# <h3>Grading succeeded</h3>
# <h6 style="color: green;">TEST Test 1_1 , Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>
# <h6 style="color: green;">TEST Test 1_2 , Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>
# <h6 style="color: green;">TEST Test 1_3 , Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>
# <h6 style="color: green;">TEST Test 2_1 , Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>
# <h6 style="color: green;">TEST Test 2_2 , Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>
# <h6 style="color: green;">TEST Test 2_3 , Your test grade: 100</h6>
# <h6>Feedback: Probando código</h6>
# <h3 style="color: purple;">Your submission grade: "100.0%"</h3>

# %% [markdown]
# ## **Créditos**
# ---
#
# * **Profesor:** [Felipe Restrepo Calle](https://dis.unal.edu.co/~ferestrepoca/)
# * **Asistente docente:** Alberto Nicolai Romero Martínez
#
# **Universidad Nacional de Colombia** - *Facultad de Ingeniería*
