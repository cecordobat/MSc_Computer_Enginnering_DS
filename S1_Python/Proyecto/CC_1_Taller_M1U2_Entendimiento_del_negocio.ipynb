# %% [markdown]
# <img src = "https://drive.google.com/uc?export=view&id=1ljiY7gV0TKs3nnTMPA5UBdED8KGzzZnX" alt = "Encabezado MLDS" width = "100%">  </img>

# %% [markdown]
# # **Entendimiento del negocio**
# ---
# Este notebook es una plantilla que le puede servir como guía para el primer entregable del proyecto aplicado.

# %% [markdown]
# ## **0. Integrantes del equipo de trabajo**
# ---
#
# Por favor incluya los nombres completos y número de identificación de los integrantes del equipo de trabajo:

# %% [markdown]
# 1. Laura Daniela Zambrano Guacheta
# 2. Cristhian Enrique Córdoba Trillos

# %% [markdown]
# ## **1. Marco de Proyecto**
# ---
#
# El taller "Prevención de Enfermedades Cardíacas y Accidentes Cerebrovasculares" se centrará en el análisis de datos para identificar patrones y factores de riesgo en la población.
#
# Mediante el análisis de datos, técnicas de análisis predictivo y machine learning, se buscará mejorar la detección temprana y la personalización de intervenciones preventivas, optimizando recursos y estrategias de salud pública.

# %% [markdown]
# ### **1.1. Trasfondo del Negocio**
# ---
# Los beneficiarios del proyecto son personas en riesgo de sufrir enfermedades cardíacas y accidentes cerebrovasculares, así como profesionales de la salud. El proyecto se encuentra en el dominio de la medicina, con un enfoque en la prevención.
#
# Los principales desafíos incluyen la identificación temprana de factores de riesgo, la personalización de intervenciones y la gestión de grandes volúmenes de datos para mejorar la predicción y prevención de estas afecciones.

# %% [markdown]
# ### **1.2. Alcance**
# ---
#
# 1. **¿Qué solución se desea implementar?**
#    Se desea implementar una solución basada en análisis estadístico y machine learning para identificar factores de riesgo, personalizar intervenciones preventivas, y mejorar la detección temprana de enfermedades cardíacas y accidentes cerebrovasculares.
#
# 2. **¿Cuáles son los límites y fronteras del proyecto de análisis de datos?**
#    El proyecto se centrará en el análisis de datos médicos y clínicos para la prevención de enfermedades.
#    Se incluirán datos poblacionales, patrones de riesgo y recomendaciones preventivas, pero no se abordarán otros temas como marketing o ventas.
#
# 3. **¿De qué forma el cliente o beneficiario utilizará el producto del proyecto?**
#    Los beneficiarios, como médicos y profesionales de la salud, utilizarán el producto para mejorar la toma de decisiones clínicas, personalizar recomendaciones preventivas y optimizar programas de salud pública enfocados en reducir la incidencia de enfermedades cardíacas y accidentes cerebrovasculares. Al mismo tiempo, puede ser de ayuda para la ejecución de políticas públicas en el país.

# %% [markdown]
# Utilizaremos una regresión múltiple que empleará como covariables la información clínica del paciente, incluyendo edad, raza, patrones de comportamiento y características morfo-fisiológicas de la enfermedad.
#
# Este enfoque permitirá identificar las relaciones entre estas variables y los riesgos de enfermedades cardíacas y accidentes cerebrovasculares, mejorando la precisión en la predicción y personalización de las intervenciones preventivas.

# %% [markdown]
# ### **1.3. Plan**
# ---
#
# Faltaría agregar esta parte del ejemplo:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **2. Datos**
# ---
#
# En esta sección se presentará una descripción detallada de los datos clínicos que se utilizarán para el análisis, incluyendo variables como la edad, raza, patrones de comportamiento, entre otros.
#
# Estos datos serán clave para alimentar los modelos predictivos y obtener conclusiones relevantes en la prevención de enfermedades cardíacas y accidentes cerebrovasculares.
#
# La fuente de datos es la siguiente:
#
# https://catalog.data.gov/dataset/behavioral-risk-factor-data-heart-disease-amp-stroke-prevention

# %% [markdown]
# ### **2.1. Origen**
# ---

# %% [markdown]
# El **BRFSS** (Sistema de Vigilancia de Factores de Riesgo Conductuales) es un sistema de vigilancia continuo, basado en los estados, que recopila información sobre factores de riesgo modificables para enfermedades crónicas y otras principales causas de muerte. Los indicadores de esta fuente de datos han sido calculados por el personal de la División para la Prevención de Enfermedades Cardíacas y Accidentes Cerebrovasculares (DHDSP) del **CDC**.
#
# Este sistema proporciona información clave sobre los factores de riesgo conductuales para ayudar en la prevención de enfermedades cardíacas y accidentes cerebrovasculares.
#
# https://data.world/us-hhs-gov/c5c07d9c-863c-4d4d-b519-4a2662032fb8
